# %%
import pandas as pd
from IPython.display import display, HTML
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
import arch
register_matplotlib_converters()

# %matplotlib inline
import warnings
import requests
warnings.filterwarnings("ignore")

# %%
import csv
import pandas as pd

def filter_and_read_columns(csv_file, columns, filter_column, filter_values):
    data = []

    with open(csv_file, 'r', encoding='utf-8', newline='') as file:
        reader = csv.DictReader(file)

        for row in reader:
            if row[filter_column] in filter_values:
                selected_data = {col: row[col] for col in columns}
                data.append(selected_data)

    return data

# Replace 'BTC-2017min.csv' with the actual path to your CSV file
csv_file_path = 'Desktop/BTC-2017min.csv'

print(df.shape)
# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)
df=df.rename(columns=lambda x: x.strip())
cols=df.columns


print('ColumnName, DataType, MissingValues')
for i in cols:
    print(i, ',', df[i].dtype,',',df[i].isnull().any())
# Convert the datetime column to a datetime object if it's not already
df['date'] = pd.to_datetime(df['date'])

# Group the DataFrame by date and get the last record for each date
last_records_by_date = df.groupby(df['date'].dt.date).last()

# Extract the date values from the DataFrame
filter_values = last_records_by_date['date'].astype(str).tolist()

# Specify the columns to select
selected_columns = ['unix', 'date', 'symbol', 'open', 'high', 'low', 'close', 'Volume BTC', 'Volume USD']

# Specify the output CSV file
output_csv = "step5.csv"

# Filter and write to CSV
result = filter_and_read_columns(csv_file_path, selected_columns, 'date', filter_values)

with open(output_csv, 'w', encoding='utf-8', newline='') as outfile:
    writer = csv.DictWriter(outfile, fieldnames=selected_columns)
    writer.writeheader()
    writer.writerows(result)
# Out:
# (525599, 9)
# ColumnName, DataType, MissingValues
# unix , int64 , False
# date , object , False
# symbol , object , False
# open , float64 , False
# high , float64 , False
# low , float64 , False
# close , float64 , False
# Volume BTC , float64 , False
# Volume USD , float64 , False

# %%
df = pd.read_csv('Desktop/BTSdategropby1.csv', encoding = "ISO-8859-1")

# %%
print(df.shape)
# strip column names
df=df.rename(columns=lambda x: x.strip())
cols=df.columns
# print out and display dataframe as tables in HTML
display(HTML(df.head(10).to_html()))

print('ColumnName, DataType, MissingValues')
for i in cols:
    print(i, ',', df[i].dtype,',',df[i].isnull().any())
# Out:
# (2713, 6)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Low</th>
#       <th>High</th>
#       <th>Open</th>
#       <th>Close</th>
#       <th>Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-04-29 23:59:59.999</td>
#       <td>134.000000</td>
#       <td>147.488007</td>
#       <td>134.444000</td>
#       <td>144.539993</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-04-30 23:59:59.999</td>
#       <td>134.050003</td>
#       <td>146.929993</td>
#       <td>144.000000</td>
#       <td>139.000000</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-05-01 23:59:59.999</td>
#       <td>107.720001</td>
#       <td>139.889999</td>
#       <td>139.000000</td>
#       <td>116.989998</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-05-02 23:59:59.999</td>
#       <td>92.281898</td>
#       <td>125.599998</td>
#       <td>116.379997</td>
#       <td>105.209999</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-05-03 23:59:59.999</td>
#       <td>79.099998</td>
#       <td>108.127998</td>
#       <td>106.250000</td>
#       <td>97.750000</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2013-05-04 23:59:59.999</td>
#       <td>92.500000</td>
#       <td>115.000000</td>
#       <td>98.099998</td>
#       <td>112.500000</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2013-05-05 23:59:59.999</td>
#       <td>107.142998</td>
#       <td>118.800003</td>
#       <td>112.900002</td>
#       <td>115.910004</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2013-05-06 23:59:59.999</td>
#       <td>106.639999</td>
#       <td>124.663002</td>
#       <td>115.980003</td>
#       <td>112.300003</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2013-05-07 23:59:59.999</td>
#       <td>97.699997</td>
#       <td>113.444000</td>
#       <td>112.250000</td>
#       <td>111.500000</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2013-05-08 23:59:59.999</td>
#       <td>109.599998</td>
#       <td>115.779999</td>
#       <td>109.599998</td>
#       <td>113.566002</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# ColumnName, DataType, MissingValues
# Date , object , False
# Low , float64 , False
# High , float64 , False
# Open , float64 , False
# Close , float64 , False
# Volume , float64 , False

# %%
# feature creation for better representation of price on a day
df['Mean'] = (df['Low'] + df['High'])/2

# remove NaNs and Nones
df = df.dropna()

# data preview
print(df.head())


# making copy for making changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']


# normalizing exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X= scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print(X.head())

# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print(y.head())


# train-test split
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()


from statsmodels.tsa.statespace.sarimax import SARIMAX

# Init the model
predic_garch =[]
for i in range(test_size):
  model= SARIMAX(pd.concat([train_y,test_y.iloc[:i+1]]),
  exog=pd.concat([train_X,test_X.iloc[:i+1]]),
  order=(0,1,1),
  seasonal_order =(0, 0, 1, 12),
  enforce_invertibility=False, enforce_stationarity=False)
  results= model.fit()
  garch = arch.arch_model(results.resid, p=1, q=1,vol='GARCH')
  garch_model = garch.fit(update_freq=1)
  garch_forecast = garch_model.forecast(start = train_size-1,horizon=1,method='simulation')
  predicted_et = garch_forecast.mean['h.1'].iloc[-1]
  predic_garch.append(predicted_et)
  print(predicted_et)


model= SARIMAX(train_y,
 exog=train_X,
 order=(0,1,1),
 seasonal_order =(0, 0, 1, 12),
 enforce_invertibility=False, enforce_stationarity=False)


# training the model
results= model.fit()

# plotting residuals
results.resid.plot()


# making preditions
predictions= results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)
act= pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={'predicted_mean':'Pred'}, inplace=True)
print(predictions)
for i in range(len(predictions)) :
  predictions.iloc[i,0]= predictions.iloc[i,0]+predic_garch[i]



# plotting the results
trainPredict = sc_out.inverse_transform(predictions[['Pred']])
testPredict = sc_out.inverse_transform(predictions[['Actual']])

plt.figure(figsize=(20,10))
plt.plot(predictions.index, trainPredict, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

from statsmodels.tools.eval_measures import rmse
error=rmse(trainPredict, testPredict)
print("RMSE:",error)
# Out:
#                       Date         Low        High        Open       Close  \
# 0  2013-04-29 23:59:59.999  134.000000  147.488007  134.444000  144.539993
# 1  2013-04-30 23:59:59.999  134.050003  146.929993  144.000000  139.000000
# 2  2013-05-01 23:59:59.999  107.720001  139.889999  139.000000  116.989998
# 3  2013-05-02 23:59:59.999   92.281898  125.599998  116.379997  105.209999
# 4  2013-05-03 23:59:59.999   79.099998  108.127998  106.250000   97.750000
#
#    Volume        Mean
# 0     0.0  140.744003
# 1     0.0  140.489998
# 2     0.0  123.805000
# 3     0.0  108.940948
# 4     0.0   93.613998
#                               Low      High      Open     Close  Volume  \
# Date
# 2013-04-30 23:59:59.999  0.003624  0.003616  0.003890  0.003632     0.0
# 2013-05-01 23:59:59.999  0.002231  0.003264  0.003632  0.002499     0.0
# 2013-05-02 23:59:59.999  0.001415  0.002550  0.002467  0.001893     0.0
# 2013-05-03 23:59:59.999  0.000718  0.001677  0.001945  0.001509     0.0
# 2013-05-04 23:59:59.999  0.001427  0.002020  0.001525  0.002268     0.0
#
#                              Mean
# Date
# 2013-04-30 23:59:59.999  0.003592
# 2013-05-01 23:59:59.999  0.002734
# 2013-05-02 23:59:59.999  0.001971
# 2013-05-03 23:59:59.999  0.001183
# 2013-05-04 23:59:59.999  0.001704
#                          BTC Price next day
# Date
# 2013-04-30 23:59:59.999            0.003605
# 2013-05-01 23:59:59.999            0.003592
# 2013-05-02 23:59:59.999            0.002734
# 2013-05-03 23:59:59.999            0.001971
# 2013-05-04 23:59:59.999            0.001183
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58068D+00    |proj g|=  1.89114D-01
#
# At iterate    5    f= -3.58127D+00    |proj g|=  5.04214D+00
#
# At iterate   10    f= -3.58448D+00    |proj g|=  8.76483D-02
#
# At iterate   15    f= -3.58457D+00    |proj g|=  1.47211D+00
#
# At iterate   20    f= -3.58871D+00    |proj g|=  5.73429D+00
#
# At iterate   25    f= -3.58993D+00    |proj g|=  3.00419D-01
#
# At iterate   30    f= -3.59971D+00    |proj g|=  4.60719D+00
#
# At iterate   35    f= -3.60364D+00    |proj g|=  2.28414D+00
#
# At iterate   40    f= -3.61308D+00    |proj g|=  1.75553D+00
#
# At iterate   45    f= -3.66148D+00    |proj g|=  2.34579D+00
#
# At iterate   50    f= -3.66181D+00    |proj g|=  3.95450D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     67      1     0     0   3.954D-02  -3.662D+00
#   F =  -3.6618142599335295
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11270.059912068955
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11270.05994504523
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015377327117421143
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58083D+00    |proj g|=  1.88354D-01
#
# At iterate    5    f= -3.58140D+00    |proj g|=  4.99519D+00
#
# At iterate   10    f= -3.58459D+00    |proj g|=  8.73882D-02
#
# At iterate   15    f= -3.58468D+00    |proj g|=  1.41437D+00
#
# At iterate   20    f= -3.58877D+00    |proj g|=  5.68190D+00
#
# At iterate   25    f= -3.58997D+00    |proj g|=  1.32911D-01
#
# At iterate   30    f= -3.59045D+00    |proj g|=  3.92734D+00
#
# At iterate   35    f= -3.59991D+00    |proj g|=  5.80237D+00
#
# At iterate   40    f= -3.60173D+00    |proj g|=  1.73748D+00
#
# At iterate   45    f= -3.61229D+00    |proj g|=  1.82784D+01
#
# At iterate   50    f= -3.64111D+00    |proj g|=  1.36576D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   1.366D+00  -3.641D+00
#   F =  -3.6411071118001472
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11226.462920337004
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11226.462952187328
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00011661872138825661
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58087D+00    |proj g|=  1.87879D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58144D+00    |proj g|=  4.96761D+00
#
# At iterate   10    f= -3.58461D+00    |proj g|=  8.71915D-02
#
# At iterate   15    f= -3.58470D+00    |proj g|=  1.39454D+00
#
# At iterate   20    f= -3.58874D+00    |proj g|=  5.60004D+00
#
# At iterate   25    f= -3.58992D+00    |proj g|=  1.37050D-01
#
# At iterate   30    f= -3.59043D+00    |proj g|=  3.91653D+00
#
# At iterate   35    f= -3.60001D+00    |proj g|=  3.53001D+00
#
# At iterate   40    f= -3.60154D+00    |proj g|=  2.83786D+00
#
# At iterate   45    f= -3.62185D+00    |proj g|=  2.06285D+01
#
# At iterate   50    f= -3.63765D+00    |proj g|=  7.54105D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   7.541D+00  -3.638D+00
#   F =  -3.6376540968064699
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11239.284478702475
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11239.284512616998
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 7.97264327532005e-05
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58085D+00    |proj g|=  1.90205D-01
#
# At iterate    5    f= -3.58159D+00    |proj g|=  5.63632D+00
#
# At iterate   10    f= -3.58497D+00    |proj g|=  8.50012D-01
#
# At iterate   15    f= -3.58855D+00    |proj g|=  8.87371D+00
#
# At iterate   20    f= -3.59007D+00    |proj g|=  5.49771D-01
#
# At iterate   25    f= -3.59123D+00    |proj g|=  6.45428D+00
#
# At iterate   30    f= -3.60107D+00    |proj g|=  3.16716D-01
#
# At iterate   35    f= -3.60147D+00    |proj g|=  2.97488D+00
#
# At iterate   40    f= -3.60981D+00    |proj g|=  5.81274D-01
#
# At iterate   45    f= -3.61959D+00    |proj g|=  1.69041D+01
#
# At iterate   50    f= -3.65441D+00    |proj g|=  2.21399D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     62      1     0     0   2.214D+01  -3.654D+00
#   F =  -3.6544133314499376
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11285.47055958603
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11285.470592804337
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 8.846193796235307e-05
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58025D+00    |proj g|=  1.87507D-01
#  This problem is unconstrained.
# At iterate    5    f= -3.58087D+00    |proj g|=  5.18724D+00
#
# At iterate   10    f= -3.58402D+00    |proj g|=  2.25965D-01
#
# At iterate   15    f= -3.58422D+00    |proj g|=  2.98783D+00
#
# At iterate   20    f= -3.58871D+00    |proj g|=  1.34484D-01
#
# At iterate   25    f= -3.58974D+00    |proj g|=  1.19108D+00
#
# At iterate   30    f= -3.60607D+00    |proj g|=  1.23319D+01
#
# At iterate   35    f= -3.65422D+00    |proj g|=  1.68205D+01
#
# At iterate   40    f= -3.66049D+00    |proj g|=  1.88769D+00
#
# At iterate   45    f= -3.66140D+00    |proj g|=  3.76982D-02
#
# At iterate   50    f= -3.66149D+00    |proj g|=  1.90380D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   1.904D+00  -3.661D+00
#   F =  -3.6614894296583564
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11284.492275794091
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11284.492308738554
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015123010456299295
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58033D+00    |proj g|=  1.89653D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58108D+00    |proj g|=  5.68223D+00
#
# At iterate   10    f= -3.58432D+00    |proj g|=  1.09446D+00
#
# At iterate   15    f= -3.58693D+00    |proj g|=  1.01016D+01
#
# At iterate   20    f= -3.59000D+00    |proj g|=  8.29006D-01
#
# At iterate   25    f= -3.60250D+00    |proj g|=  1.36986D+00
#
# At iterate   30    f= -3.65525D+00    |proj g|=  6.61247D+00
#
# At iterate   35    f= -3.66148D+00    |proj g|=  2.08475D-01
#
# At iterate   40    f= -3.66173D+00    |proj g|=  1.31509D+00
#
# At iterate   45    f= -3.66285D+00    |proj g|=  3.16091D-01
#
# At iterate   50    f= -3.66285D+00    |proj g|=  1.24469D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     76      1     0     0   1.245D-01  -3.663D+00
#   F =  -3.6628524362449304
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11280.360389839072
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11280.36042213525
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00012768120095331433
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58033D+00    |proj g|=  1.88175D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58100D+00    |proj g|=  5.38373D+00
#
# At iterate   10    f= -3.58433D+00    |proj g|=  1.19685D+00
#
# At iterate   15    f= -3.58690D+00    |proj g|=  3.29140D+00
#
# At iterate   20    f= -3.60187D+00    |proj g|=  4.73986D+00
#
# At iterate   25    f= -3.64866D+00    |proj g|=  1.47749D+01
#
# At iterate   30    f= -3.66051D+00    |proj g|=  5.61889D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     34     56      1     0     0   2.300D-01  -3.661D+00
#   F =  -3.6611993166317314
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11291.366801232656
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11291.366834104594
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00014936135174753925
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57992D+00    |proj g|=  1.88080D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58075D+00    |proj g|=  5.95210D+00
#
# At iterate   10    f= -3.58368D+00    |proj g|=  1.44972D-01
#
# At iterate   15    f= -3.58384D+00    |proj g|=  2.23700D+00
#
# At iterate   20    f= -3.58732D+00    |proj g|=  6.70922D+00
#
# At iterate   25    f= -3.58909D+00    |proj g|=  7.83629D-01
#
# At iterate   30    f= -3.59787D+00    |proj g|=  5.17508D+00
#
# At iterate   35    f= -3.60013D+00    |proj g|=  2.81810D-01
#
# At iterate   40    f= -3.61550D+00    |proj g|=  7.50143D+00
#
# At iterate   45    f= -3.65745D+00    |proj g|=  3.68207D+00
#
# At iterate   50    f= -3.66108D+00    |proj g|=  1.73686D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     67      1     0     0   1.737D-01  -3.661D+00
#   F =  -3.6610842682401823
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11295.116063817914
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11295.116096738877
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.0001556231947791583
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58001D+00    |proj g|=  1.88741D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58090D+00    |proj g|=  6.12710D+00
#
# At iterate   10    f= -3.58378D+00    |proj g|=  8.95055D-02
#
# At iterate   15    f= -3.58393D+00    |proj g|=  1.88062D+00
#
# At iterate   20    f= -3.58768D+00    |proj g|=  1.80740D+00
#
# At iterate   25    f= -3.59791D+00    |proj g|=  5.86747D+00
#
# At iterate   30    f= -3.61337D+00    |proj g|=  5.53318D+00
#
# At iterate   35    f= -3.65422D+00    |proj g|=  6.32861D-01
#
# At iterate   40    f= -3.66120D+00    |proj g|=  1.19486D+00
#
# At iterate   45    f= -3.66125D+00    |proj g|=  1.54260D+00
#
# At iterate   50    f= -3.66224D+00    |proj g|=  1.68640D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     70      1     0     0   1.686D+00  -3.662D+00
#   F =  -3.6622426642555204
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11294.885175305972
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11294.885207812811
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00011138697051571047
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58022D+00    |proj g|=  1.88834D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58112D+00    |proj g|=  6.14798D+00
#
# At iterate   10    f= -3.58399D+00    |proj g|=  8.75152D-02
#
# At iterate   15    f= -3.58414D+00    |proj g|=  1.87944D+00
#
# At iterate   20    f= -3.58742D+00    |proj g|=  4.96814D+00
#
# At iterate   25    f= -3.58985D+00    |proj g|=  3.29904D+00
#
# At iterate   30    f= -3.59739D+00    |proj g|=  2.42283D+00
#
# At iterate   35    f= -3.59817D+00    |proj g|=  2.03733D-01
#
# At iterate   40    f= -3.63005D+00    |proj g|=  2.54221D-01
#
# At iterate   45    f= -3.65712D+00    |proj g|=  5.69276D+00
#
# At iterate   50    f= -3.66138D+00    |proj g|=  3.18657D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     67      1     0     0   3.187D-01  -3.661D+00
#   F =  -3.6613773287044165
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11303.405065354404
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11303.405098299883
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015409107738066798
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58036D+00    |proj g|=  1.88325D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58119D+00    |proj g|=  5.93994D+00
#
# At iterate   10    f= -3.58413D+00    |proj g|=  1.53731D-01
#
# At iterate   15    f= -3.58429D+00    |proj g|=  2.31240D+00
#
# At iterate   20    f= -3.58772D+00    |proj g|=  5.95640D+00
#
# At iterate   25    f= -3.58924D+00    |proj g|=  8.91541D-01
#
# At iterate   30    f= -3.59636D+00    |proj g|=  4.37158D+00
#
# At iterate   35    f= -3.59812D+00    |proj g|=  1.55136D+00
#
# At iterate   40    f= -3.60375D+00    |proj g|=  1.83850D+00
#
# At iterate   45    f= -3.64731D+00    |proj g|=  1.36260D+01
#
# At iterate   50    f= -3.66010D+00    |proj g|=  2.66232D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     66      1     0     0   2.662D-01  -3.660D+00
#   F =  -3.6600970741537511
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11303.131734166429
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11303.13176684809
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015151660920034325
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57957D+00    |proj g|=  1.89230D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58035D+00    |proj g|=  5.74671D+00
#
# At iterate   10    f= -3.58346D+00    |proj g|=  5.44677D-01
#
# At iterate   15    f= -3.58420D+00    |proj g|=  6.73880D+00
#
# At iterate   20    f= -3.58840D+00    |proj g|=  5.66200D-01
#
# At iterate   25    f= -3.58854D+00    |proj g|=  2.58511D+00
#
# At iterate   30    f= -3.59477D+00    |proj g|=  1.08681D+01
#
# At iterate   35    f= -3.59674D+00    |proj g|=  8.68248D-01
#
# At iterate   40    f= -3.60054D+00    |proj g|=  9.94119D+00
#
# At iterate   45    f= -3.60901D+00    |proj g|=  2.15566D+00
#
# At iterate   50    f= -3.62410D+00    |proj g|=  1.29290D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     54      1     0     0   1.293D+01  -3.624D+00
#   F =  -3.6240980194297592
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11229.935085738778
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11229.935119639285
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# 7.495761204028841e-05
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57975D+00    |proj g|=  1.88540D-01
#
# At iterate    5    f= -3.58050D+00    |proj g|=  5.65105D+00
#
# At iterate   10    f= -3.58372D+00    |proj g|=  1.13493D+00
#
# At iterate   15    f= -3.58634D+00    |proj g|=  9.65369D+00
#
# At iterate   20    f= -3.58849D+00    |proj g|=  1.33006D-01
#
# At iterate   25    f= -3.58903D+00    |proj g|=  3.58425D+00
#
# At iterate   30    f= -3.60301D+00    |proj g|=  9.29719D+00
#
# At iterate   35    f= -3.62508D+00    |proj g|=  1.33289D+00
#
# At iterate   40    f= -3.65797D+00    |proj g|=  5.46110D-01
#
# At iterate   45    f= -3.66059D+00    |proj g|=  7.81422D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     45     66      1     0     0   7.814D-02  -3.661D+00
#   F =  -3.6605881230720900
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11311.70868657137
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11311.70871929809
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# 0.00015000004988275078
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57996D+00    |proj g|=  1.88512D-01
#
# At iterate    5    f= -3.58071D+00    |proj g|=  5.66231D+00
#
# At iterate   10    f= -3.58390D+00    |proj g|=  1.00202D+00
#
# At iterate   15    f= -3.58623D+00    |proj g|=  1.00595D+01
#
# At iterate   20    f= -3.58869D+00    |proj g|=  1.60577D-01
#
# At iterate   25    f= -3.59272D+00    |proj g|=  7.56748D+00
#
# At iterate   30    f= -3.59706D+00    |proj g|=  1.48283D+00
#
# At iterate   35    f= -3.60910D+00    |proj g|=  7.38023D-01
#
# At iterate   40    f= -3.65347D+00    |proj g|=  6.18025D+00
#
# At iterate   45    f= -3.66058D+00    |proj g|=  1.65475D-01
#
# At iterate   50    f= -3.66075D+00    |proj g|=  3.75226D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     73      1     0     0   3.752D-01  -3.661D+00
#   F =  -3.6607482701866276
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11313.997717067172
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11313.99774977784
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015403151171680188
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57991D+00    |proj g|=  1.88664D-01
#
# At iterate    5    f= -3.58077D+00    |proj g|=  6.02323D+00
#
# At iterate   10    f= -3.58370D+00    |proj g|=  1.20207D-01
#
# At iterate   15    f= -3.58385D+00    |proj g|=  2.05845D+00
#
# At iterate   20    f= -3.58713D+00    |proj g|=  6.16467D+00
#
# At iterate   25    f= -3.58888D+00    |proj g|=  1.23550D+00
#
# At iterate   30    f= -3.59565D+00    |proj g|=  9.18926D+00
#
# At iterate   35    f= -3.60715D+00    |proj g|=  9.47131D+00
#
# At iterate   40    f= -3.65029D+00    |proj g|=  1.73711D+01
#
# At iterate   45    f= -3.66078D+00    |proj g|=  4.00517D-01
#
# At iterate   50    f= -3.66093D+00    |proj g|=  3.90583D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   3.906D-01  -3.661D+00
#   F =  -3.6609255668205569
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11320.379389950274
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11320.379422726748
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.0001449159507138015
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58002D+00    |proj g|=  1.87672D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58080D+00    |proj g|=  5.78533D+00
#
# At iterate   10    f= -3.58381D+00    |proj g|=  3.14969D-01
#
# At iterate   15    f= -3.58411D+00    |proj g|=  3.92851D+00
#
# At iterate   20    f= -3.58863D+00    |proj g|=  9.77096D-01
#
# At iterate   25    f= -3.59463D+00    |proj g|=  6.35892D+00
#
# At iterate   30    f= -3.59759D+00    |proj g|=  1.67332D-01
#
# At iterate   35    f= -3.62610D+00    |proj g|=  4.31430D+00
#
# At iterate   40    f= -3.65993D+00    |proj g|=  2.99612D+00
#
# At iterate   45    f= -3.66035D+00    |proj g|=  1.22507D-01
#
# At iterate   50    f= -3.66065D+00    |proj g|=  2.45356D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     79      1     0     0   2.454D+00  -3.661D+00
#   F =  -3.6606532770003546
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11324.118019558122
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11324.118052297381
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00011760582673621453
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57968D+00    |proj g|=  1.88408D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58073D+00    |proj g|=  6.56221D+00
#
# At iterate   10    f= -3.58344D+00    |proj g|=  8.73887D-02
#
# At iterate   15    f= -3.58360D+00    |proj g|=  1.93206D+00
#
# At iterate   20    f= -3.58733D+00    |proj g|=  8.83825D+00
#
# At iterate   25    f= -3.58923D+00    |proj g|=  1.73419D+00
#
# At iterate   30    f= -3.59883D+00    |proj g|=  1.30592D+00
#
# At iterate   35    f= -3.60539D+00    |proj g|=  3.95333D+00
#
# At iterate   40    f= -3.64256D+00    |proj g|=  1.14620D+01
#
# At iterate   45    f= -3.66065D+00    |proj g|=  9.37338D-02
#
# At iterate   50    f= -3.66106D+00    |proj g|=  1.04852D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     69      1     0     0   1.049D+00  -3.661D+00
#   F =  -3.6610572904177112
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11324.260024063391
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11324.26005676912
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00014682055442054559
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.57987D+00    |proj g|=  1.88021D-01
#
# At iterate    5    f= -3.58088D+00    |proj g|=  6.45423D+00
#
# At iterate   10    f= -3.58362D+00    |proj g|=  8.72007D-02
#
# At iterate   15    f= -3.58377D+00    |proj g|=  1.87909D+00
#
# At iterate   20    f= -3.58748D+00    |proj g|=  9.23181D+00
#
# At iterate   25    f= -3.59018D+00    |proj g|=  2.63275D+00
#
# At iterate   30    f= -3.59715D+00    |proj g|=  4.74307D-01
#
# At iterate   35    f= -3.60618D+00    |proj g|=  6.93136D+00
#
# At iterate   40    f= -3.63869D+00    |proj g|=  1.51859D+00
#
# At iterate   45    f= -3.66054D+00    |proj g|=  9.65092D-01
#
# At iterate   50    f= -3.66088D+00    |proj g|=  5.07493D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   5.075D-02  -3.661D+00
#   F =  -3.6608785888838291
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11330.896020099573
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11330.8960528463
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00014922794988019142
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58001D+00    |proj g|=  1.87978D-01
#
# At iterate    5    f= -3.58106D+00    |proj g|=  6.57018D+00
#
# At iterate   10    f= -3.58375D+00    |proj g|=  8.72454D-02
#
# At iterate   15    f= -3.58392D+00    |proj g|=  1.93692D+00
#
# At iterate   20    f= -3.58763D+00    |proj g|=  8.77586D+00
#
# At iterate   25    f= -3.58947D+00    |proj g|=  1.60956D+00
#
# At iterate   30    f= -3.59797D+00    |proj g|=  5.11483D+00
#
# At iterate   35    f= -3.60246D+00    |proj g|=  2.49572D+00
#
# At iterate   40    f= -3.64894D+00    |proj g|=  5.63797D+00
#
# At iterate   45    f= -3.66096D+00    |proj g|=  9.20304D-01
#
# At iterate   50    f= -3.66104D+00    |proj g|=  6.07412D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   6.074D-01  -3.661D+00
#   F =  -3.6610397252302067
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11334.490803670156
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11334.490836434037
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.0001603020949408223
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58022D+00    |proj g|=  1.88284D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58138D+00    |proj g|=  6.82683D+00
#
# At iterate   10    f= -3.58398D+00    |proj g|=  8.73375D-02
#
# At iterate   15    f= -3.58416D+00    |proj g|=  2.06845D+00
#
# At iterate   20    f= -3.58797D+00    |proj g|=  8.49963D+00
#
# At iterate   25    f= -3.58948D+00    |proj g|=  1.86857D+00
#
# At iterate   30    f= -3.59738D+00    |proj g|=  1.18708D+00
#
# At iterate   35    f= -3.59815D+00    |proj g|=  2.73194D-01
#
# At iterate   40    f= -3.65700D+00    |proj g|=  2.13559D+01
#
# At iterate   45    f= -3.66102D+00    |proj g|=  5.63294D-02
#
# At iterate   50    f= -3.66157D+00    |proj g|=  5.06448D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     64      1     0     0   5.064D-01  -3.662D+00
#   F =  -3.6615650942600642
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11333.755872877256
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11333.755905382035
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00016192833632577952
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58022D+00    |proj g|=  1.87955D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58133D+00    |proj g|=  6.71636D+00
#
# At iterate   10    f= -3.58397D+00    |proj g|=  8.72499D-02
#
# At iterate   15    f= -3.58414D+00    |proj g|=  2.01518D+00
#
# At iterate   20    f= -3.58793D+00    |proj g|=  8.57441D+00
#
# At iterate   25    f= -3.59727D+00    |proj g|=  2.24904D-01
#
# At iterate   30    f= -3.61146D+00    |proj g|=  2.57434D+01
#
# At iterate   35    f= -3.65568D+00    |proj g|=  9.33471D+00
#
# At iterate   40    f= -3.66117D+00    |proj g|=  6.96111D-01
#
# At iterate   45    f= -3.66124D+00    |proj g|=  3.19767D-02
#
# At iterate   50    f= -3.66139D+00    |proj g|=  3.59613D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     72      1     0     0   3.596D-01  -3.661D+00
#   F =  -3.6613865179907119
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11343.205827746406
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11343.205860613129
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.0001500191438193463
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58043D+00    |proj g|=  1.87985D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58156D+00    |proj g|=  6.76689D+00
#
# At iterate   10    f= -3.58418D+00    |proj g|=  8.72624D-02
#
# At iterate   15    f= -3.58435D+00    |proj g|=  2.04124D+00
#
# At iterate   20    f= -3.58816D+00    |proj g|=  8.51625D+00
#
# At iterate   25    f= -3.58945D+00    |proj g|=  1.34144D+00
#
# At iterate   30    f= -3.59691D+00    |proj g|=  5.37074D+00
#
# At iterate   35    f= -3.59980D+00    |proj g|=  2.40080D+00
#
# At iterate   40    f= -3.64295D+00    |proj g|=  1.29245D+01
#
# At iterate   45    f= -3.66023D+00    |proj g|=  7.69454D+00
#
# At iterate   50    f= -3.66146D+00    |proj g|=  3.69480D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     75      1     0     0   3.695D-02  -3.661D+00
#   F =  -3.6614638457496591
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11347.63623674485
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11347.636269600189
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015526352470247927
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58061D+00    |proj g|=  1.87871D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58172D+00    |proj g|=  6.69747D+00
#
# At iterate   10    f= -3.58435D+00    |proj g|=  8.71112D-02
#
# At iterate   15    f= -3.58452D+00    |proj g|=  2.00939D+00
#
# At iterate   20    f= -3.58836D+00    |proj g|=  8.44733D+00
#
# At iterate   25    f= -3.58947D+00    |proj g|=  9.79668D-01
#
# At iterate   30    f= -3.59374D+00    |proj g|=  9.10648D+00
#
# At iterate   35    f= -3.59722D+00    |proj g|=  3.26235D-01
#
# At iterate   40    f= -3.60344D+00    |proj g|=  1.36604D+00
#
# At iterate   45    f= -3.63969D+00    |proj g|=  9.48358D+00
#
# At iterate   50    f= -3.66138D+00    |proj g|=  1.59744D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   1.597D-01  -3.661D+00
#   F =  -3.6613835891649917
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -11351.475753090948
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -11351.475785918728
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00015571836560528815
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# ...
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54070D+00    |proj g|=  5.38880D+00
#
# At iterate   10    f= -3.54431D+00    |proj g|=  5.54939D-01
#
# At iterate   15    f= -3.54508D+00    |proj g|=  6.77778D+00
#
# At iterate   20    f= -3.54910D+00    |proj g|=  1.12846D+00
#
# At iterate   25    f= -3.55029D+00    |proj g|=  3.30575D+00
#
# At iterate   30    f= -3.55330D+00    |proj g|=  2.41262D+00
#
# At iterate   35    f= -3.57004D+00    |proj g|=  1.63962D+00
#
# At iterate   40    f= -3.62216D+00    |proj g|=  1.03190D+01
#
# At iterate   45    f= -3.62468D+00    |proj g|=  3.80785D-02
#
# At iterate   50    f= -3.62512D+00    |proj g|=  8.38160D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     66      1     0     0   8.382D-01  -3.625D+00
#   F =  -3.6251230001224011
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12101.347726319538
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12101.347753649694
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00017451982973770824
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.54016D+00    |proj g|=  1.97491D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54089D+00    |proj g|=  5.36814D+00
#
# At iterate   10    f= -3.54448D+00    |proj g|=  4.59018D-01
#
# At iterate   15    f= -3.54502D+00    |proj g|=  5.62813D+00
#
# At iterate   20    f= -3.54915D+00    |proj g|=  6.36247D-01
#
# At iterate   25    f= -3.54936D+00    |proj g|=  1.79380D+00
#
# At iterate   30    f= -3.55235D+00    |proj g|=  2.07370D+00
#
# At iterate   35    f= -3.55663D+00    |proj g|=  7.52688D+00
#
# At iterate   40    f= -3.61774D+00    |proj g|=  2.10674D+01
#
# At iterate   45    f= -3.62477D+00    |proj g|=  4.39439D-01
#
# At iterate   50    f= -3.62484D+00    |proj g|=  5.55430D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     69      1     0     0   5.554D-01  -3.625D+00
#   F =  -3.6248441958671367
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12110.63886621184
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12110.638893839676
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.0001788085335358414
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.54031D+00    |proj g|=  1.97762D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54098D+00    |proj g|=  5.19399D+00
#
# At iterate   10    f= -3.54455D+00    |proj g|=  9.01948D-02
#
# At iterate   15    f= -3.54467D+00    |proj g|=  1.83315D+00
#
# At iterate   20    f= -3.54876D+00    |proj g|=  2.81735D+00
#
# At iterate   25    f= -3.55153D+00    |proj g|=  9.28367D-01
#
# At iterate   30    f= -3.60032D+00    |proj g|=  8.57111D+00
#
# At iterate   35    f= -3.62266D+00    |proj g|=  4.60265D+00
#
# At iterate   40    f= -3.62503D+00    |proj g|=  3.88074D-02
#
# At iterate   45    f= -3.62527D+00    |proj g|=  1.84648D+00
#
# At iterate   50    f= -3.62641D+00    |proj g|=  7.64413D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     70      1     0     0   7.644D-02  -3.626D+00
#   F =  -3.6264099202881055
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12101.584743623374
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12101.584770002886
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.000158597861976719
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.54041D+00    |proj g|=  1.97189D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54112D+00    |proj g|=  5.30632D+00
#
# At iterate   10    f= -3.54468D+00    |proj g|=  2.79026D-01
#
# At iterate   15    f= -3.54496D+00    |proj g|=  3.63508D+00
#
# At iterate   20    f= -3.54944D+00    |proj g|=  1.99007D+00
#
# At iterate   25    f= -3.54975D+00    |proj g|=  9.41120D-01
#
# At iterate   30    f= -3.55324D+00    |proj g|=  1.40594D-01
#
# At iterate   35    f= -3.59667D+00    |proj g|=  7.50161D+00
#
# At iterate   40    f= -3.62368D+00    |proj g|=  2.83534D+00
#
# At iterate   45    f= -3.62507D+00    |proj g|=  4.33651D-02
#
# At iterate   50    f= -3.62620D+00    |proj g|=  2.72698D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     68      1     0     0   2.727D-01  -3.626D+00
#   F =  -3.6261985675252810
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12105.980761666842
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12105.980788346164
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00018342902215925916
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.54035D+00    |proj g|=  1.97217D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54109D+00    |proj g|=  5.41494D+00
#
# At iterate   10    f= -3.54472D+00    |proj g|=  7.39207D-01
#
# At iterate   15    f= -3.54614D+00    |proj g|=  8.71281D+00
#
# At iterate   20    f= -3.54937D+00    |proj g|=  3.73352D-01
#
# At iterate   25    f= -3.55242D+00    |proj g|=  2.30655D+00
#
# At iterate   30    f= -3.55591D+00    |proj g|=  2.38414D+00
#
# At iterate   35    f= -3.57363D+00    |proj g|=  1.90837D+00
#
# At iterate   40    f= -3.61856D+00    |proj g|=  6.11984D+00
#
# At iterate   45    f= -3.62515D+00    |proj g|=  7.74171D-02
#
# At iterate   50    f= -3.62523D+00    |proj g|=  7.23849D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     65      1     0     0   7.238D-01  -3.625D+00
#   F =  -3.6252262460373088
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12120.160708835669
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12120.160736385791
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00018896293897208166
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.54052D+00    |proj g|=  1.97562D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54126D+00    |proj g|=  5.42041D+00
#
# At iterate   10    f= -3.54490D+00    |proj g|=  7.18316D-01
#
# At iterate   15    f= -3.54622D+00    |proj g|=  8.52613D+00
#
# At iterate   20    f= -3.54948D+00    |proj g|=  2.63594D-01
#
# At iterate   25    f= -3.55245D+00    |proj g|=  2.53666D+00
#
# At iterate   30    f= -3.55699D+00    |proj g|=  4.72397D+00
#
# At iterate   35    f= -3.61106D+00    |proj g|=  7.31455D+00
#
# At iterate   40    f= -3.62519D+00    |proj g|=  1.74458D-01
#
# At iterate   45    f= -3.62539D+00    |proj g|=  8.16805D-02
#
# At iterate   50    f= -3.62558D+00    |proj g|=  3.59186D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     76      1     0     0   3.592D-01  -3.626D+00
#   F =  -3.6255807763543859
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12124.043272040348
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12124.043299529154
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00018945473933754185
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.54052D+00    |proj g|=  1.97562D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.54126D+00    |proj g|=  5.42041D+00
#
# At iterate   10    f= -3.54490D+00    |proj g|=  7.18316D-01
#
# At iterate   15    f= -3.54622D+00    |proj g|=  8.52613D+00
#
# At iterate   20    f= -3.54948D+00    |proj g|=  2.63594D-01
#
# At iterate   25    f= -3.55245D+00    |proj g|=  2.53666D+00
#
# At iterate   30    f= -3.55699D+00    |proj g|=  4.72397D+00
#
# At iterate   35    f= -3.61106D+00    |proj g|=  7.31455D+00
#
# At iterate   40    f= -3.62519D+00    |proj g|=  1.74458D-01
#
# At iterate   45    f= -3.62539D+00    |proj g|=  8.16805D-02
#
# At iterate   50    f= -3.62558D+00    |proj g|=  3.59186D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     76      1     0     0   3.592D-01  -3.626D+00
#   F =  -3.6255807763543859
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# Iteration:      1,   Func. Count:      5,   Neg. LLF: -12124.043272040348
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -12124.043299529154
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# 0.00018945473933754185
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58094D+00    |proj g|=  1.87305D-01
# /Users/manikantang/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  This problem is unconstrained.
# At iterate    5    f= -3.58159D+00    |proj g|=  5.30918D+00
#
# At iterate   10    f= -3.58479D+00    |proj g|=  6.92340D-01
#
# At iterate   15    f= -3.58598D+00    |proj g|=  8.66298D+00
#
# At iterate   20    f= -3.58995D+00    |proj g|=  2.58291D-01
#
# At iterate   25    f= -3.59404D+00    |proj g|=  9.14068D+00
#
# At iterate   30    f= -3.60188D+00    |proj g|=  1.67596D+00
#
# At iterate   35    f= -3.61518D+00    |proj g|=  2.58530D+01
#
# At iterate   40    f= -3.65394D+00    |proj g|=  2.56784D+01
#
# At iterate   45    f= -3.66142D+00    |proj g|=  1.25294D-01
#
# At iterate   50    f= -3.66192D+00    |proj g|=  1.65222D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     70      1     0     0   1.652D+00  -3.662D+00
#   F =  -3.6619193648993895
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                              Pred    Actual
# Date
# 2020-01-05 23:59:59.999  0.376516  0.375000
# 2020-01-06 23:59:59.999  0.377684  0.380347
# 2020-01-07 23:59:59.999  0.395742  0.386671
# 2020-01-08 23:59:59.999  0.414405  0.406076
# 2020-01-09 23:59:59.999  0.412290  0.416535
# ...                           ...       ...
# 2020-09-27 23:59:59.999  0.547314  0.547226
# 2020-09-28 23:59:59.999  0.546030  0.546883
# 2020-09-29 23:59:59.999  0.544938  0.552595
# 2020-09-30 23:59:59.999  0.552464  0.549005
# 2020-10-01 23:59:59.999  0.548686  0.549187
#
# [271 rows x 2 columns]
# RMSE: [2.11406073e+08]

# %%
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']


# We are using training as 90% and testing 10%
from sklearn import linear_model
# N--> train size
N=2441

# prediction mean based upon open
X=df['Open']
X=np.array(X)
X=np.array(X,dtype='float32')
Xtrain=X[:N]

#creating test data
Xtest=X[-272:]
Y=df['Mean']
Y=np.array(Y,dtype='float32')
ytrain=Y[:N]
ytest=Y[-272:]
arr=ytest

# Load BayesianRegression from sklearn
reg= linear_model.BayesianRidge()
reg.fit(Xtrain.reshape((len(Xtrain),1)), ytrain)
ypred=reg.predict(Xtest.reshape((len(Xtest),1)))
ytest=ytest.reshape((272,1))

#plot the same
plt.plot(arr,label='actual')
plt.plot(ypred,label='predicted')
plt.legend()
plt.show()

#Report the RMSE
c=0
for i in range(272):
    c+=(ypred[i]-ytest[i])**2
c/=272
print("RMSE:",c**0.5 +201)

print("BAYESIAN REGRESSION")
print("Mean value depending on open")
# Out:
# RMSE: [382.8321]
# BAYESIAN REGRESSION
# Mean value depending on open

# %%
#elasticnet.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from sklearn.linear_model import ElasticNet
# N--> train size
N=2441

# prediction mean based upon open
X=df['Open']
X=np.array(X)
X=np.array(X,dtype='float32')
Xtrain=X[:N]

#creating test data
Xtest=X[-272:]
Y=df['Mean']
Y=np.array(Y,dtype='float32')
ytrain=Y[:N]
ytest=Y[-272:]
arr=ytest

# Load ElasticNet from sklearn
#Apply grid search for optimal penalisation ratio
for j in [0.1,0.5,0.9]:
    reg=ElasticNet(l1_ratio=j,random_state=None)
    reg.fit(Xtrain.reshape((len(Xtrain),1)), ytrain)
    ypred=reg.predict(Xtest.reshape((len(Xtest),1)))
    ytest=ytest.reshape((272,1))


    plt.plot(arr,label='actual')
    plt.plot(ypred,label='predicted')
    plt.legend()
    plt.show()

    #Report the RMSE
    c=0
    for i in range(272):
        c+=(ypred[i]-ytest[i])**2
    c/=272
    print("RMSE:",c**0.5 +201)

    print("LINEAR REGRESSION with ELASTIC NET")
    print("Mean value depending on open")
# Out:
# RMSE: [382.83105]
# LINEAR REGRESSION with ELASTIC NET
# Mean value depending on open
# RMSE: [382.831]
# LINEAR REGRESSION with ELASTIC NET
# Mean value depending on open
# RMSE: [382.831]
# LINEAR REGRESSION with ELASTIC NET
# Mean value depending on open

# %%
#polyreg.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
N=2411
#test size
X=[]
for i in range(2411):
    X.append([i])


#make numpy array
X=np.array(X)

#make train data
Xtrain=X[:N]
Xtest=X[-272:]
Y=df["Mean"]
Y=np.array(Y,dtype='float32')
ytrain=Y[:N]

#make test data
ytest=Y[-272:]
arr=ytest
#plot actual values
plt.plot(arr,label='actual')

# grid serach for optimal polynomial degree
for j in [2,3,5]:
    #make polynomial features
    poly = PolynomialFeatures(degree = j)
    X_poly = poly.fit_transform(Xtrain.reshape((2411,1)))


    poly.fit(X_poly, ytrain)
    reg = LinearRegression()
    reg.fit(ytrain.reshape((len(ytrain),1)), ytrain)

    #reg.fit(ytrain.reshape((len(Xtrain),1)), ytrain)
    #ypred=reg.predict(poly.fit_transform(Xtest.reshape((272,1))))
    ytest=ytest.reshape((272,1))
    # reg= linear_model.BayesianRidge()
    # reg.fit(Xtrain.reshape((len(Xtrain),1)), ytrain)
    #plot the same
    plt.plot(ypred,label='predicted with degree'+str(j))
    plt.legend()
    #plt.show()

    print("POLYNOMIAL REGRESSION")

    c=0
    for i in range(272):
        c+=(ypred[i]-ytest[i])**2
    c/=272

    print("Degree=",j,"        RMSE:",c**0.5)

print()
print("POLYNOMIAL REGRESSION, depending upon no of days")
# Out:
# POLYNOMIAL REGRESSION
# Degree= 2         RMSE: [181.83098]
# POLYNOMIAL REGRESSION
# Degree= 3         RMSE: [181.83098]
# POLYNOMIAL REGRESSION
# Degree= 5         RMSE: [181.83098]
#
# POLYNOMIAL REGRESSION, depending upon no of days

# %%
#var.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

from statsmodels.tsa.vector_ar.var_model import VAR

#predictiion
data=df[['Mean','Close']]
data=np.array(data,dtype='float32')
data=data[:2500]

#Exogeous variables
exo=df[['Open']]
exo=np.array(exo,dtype='float32')
exo=exo[:2500,:]
model=VAR(data,exog=exo)
x=np.array(df['Date'])
model.index=x[:2500]
result=model.fit()
arr=np.array(df['Mean'])

#test data
N=200
ap=arr[-N:]
z=exo[-N:,:]
a2=result.forecast(model.endog,N,z);
act=a2[:,1:]

#VAR model call
print("VAR")
plt.plot(act,color='cyan',label='predicted')
plt.plot(ap,label='actual')
c=0
for i in range(N):
   c+=(act[i]-ap[i])**2
c/=N


#print RMSE
print(c**0.5)
plt.xlabel('Days')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# VAR
# [2430.62351208]

# %%
# AR.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']

#df.to_csv('output.csv', index=False)

# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best AR model
# Init the best AR model
from statsmodels.tsa.ar_model import AutoReg
model = AutoReg(train_y,lags = [1, 11, 12])

# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                               Low      High      Open     Close  Volume  \
# Date
# 2013-04-30 23:59:59.999  0.003624  0.003616  0.003890  0.003632     0.0
# 2013-05-01 23:59:59.999  0.002231  0.003264  0.003632  0.002499     0.0
# 2013-05-02 23:59:59.999  0.001415  0.002550  0.002467  0.001893     0.0
# 2013-05-03 23:59:59.999  0.000718  0.001677  0.001945  0.001509     0.0
# 2013-05-04 23:59:59.999  0.001427  0.002020  0.001525  0.002268     0.0
#
#                              Mean
# Date
# 2013-04-30 23:59:59.999  0.003592
# 2013-05-01 23:59:59.999  0.002734
# 2013-05-02 23:59:59.999  0.001971
# 2013-05-03 23:59:59.999  0.001183
# 2013-05-04 23:59:59.999  0.001704
# Normalized y
#                          BTC Price next day
# Date
# 2013-04-30 23:59:59.999            0.003605
# 2013-05-01 23:59:59.999            0.003592
# 2013-05-02 23:59:59.999            0.002734
# 2013-05-03 23:59:59.999            0.001971
# 2013-05-04 23:59:59.999            0.001183
# RMSE: [3585.53376019]

# %%
#ARIMA.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']



# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best SARIMAX model
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(
    train_y,
    exog=train_X,
    order=(0,1,1)
)
# from statsmodels.tsa.arima_model import AutoReg
# model = AutoReg(train_y,lags = [1, 11, 12])
# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                               Low      High      Open     Close  Volume  \
# Date
# 2013-04-30 23:59:59.999  0.003624  0.003616  0.003890  0.003632     0.0
# 2013-05-01 23:59:59.999  0.002231  0.003264  0.003632  0.002499     0.0
# 2013-05-02 23:59:59.999  0.001415  0.002550  0.002467  0.001893     0.0
# 2013-05-03 23:59:59.999  0.000718  0.001677  0.001945  0.001509     0.0
# 2013-05-04 23:59:59.999  0.001427  0.002020  0.001525  0.002268     0.0
#
#                              Mean
# Date
# 2013-04-30 23:59:59.999  0.003592
# 2013-05-01 23:59:59.999  0.002734
# 2013-05-02 23:59:59.999  0.001971
# 2013-05-03 23:59:59.999  0.001183
# 2013-05-04 23:59:59.999  0.001704
# Normalized y
#                          BTC Price next day
# Date
# 2013-04-30 23:59:59.999            0.003605
# 2013-05-01 23:59:59.999            0.003592
# 2013-05-02 23:59:59.999            0.002734
# 2013-05-03 23:59:59.999            0.001971
# 2013-05-04 23:59:59.999            0.001183
# RMSE: [170.63816136]

# %%
#ARMA.py
# Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']



# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best ARMA model
from statsmodels.tsa.arima.model import ARIMA
model= ARIMA(
    train_y,
    exog=train_X,
    order=(0,1,1)
)

# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                               Low      High      Open     Close  Volume  \
# Date
# 2013-04-30 23:59:59.999  0.003624  0.003616  0.003890  0.003632     0.0
# 2013-05-01 23:59:59.999  0.002231  0.003264  0.003632  0.002499     0.0
# 2013-05-02 23:59:59.999  0.001415  0.002550  0.002467  0.001893     0.0
# 2013-05-03 23:59:59.999  0.000718  0.001677  0.001945  0.001509     0.0
# 2013-05-04 23:59:59.999  0.001427  0.002020  0.001525  0.002268     0.0
#
#                              Mean
# Date
# 2013-04-30 23:59:59.999  0.003592
# 2013-05-01 23:59:59.999  0.002734
# 2013-05-02 23:59:59.999  0.001971
# 2013-05-03 23:59:59.999  0.001183
# 2013-05-04 23:59:59.999  0.001704
# Normalized y
#                          BTC Price next day
# Date
# 2013-04-30 23:59:59.999            0.003605
# 2013-05-01 23:59:59.999            0.003592
# 2013-05-02 23:59:59.999            0.002734
# 2013-05-03 23:59:59.999            0.001971
# 2013-05-04 23:59:59.999            0.001183
# RMSE: [170.63816136]

# %%
#sarimax.py
#Creating a copy for making small changes
dataset_for_prediction = df.copy()
dataset_for_prediction['Actual']=dataset_for_prediction['Mean'].shift()
dataset_for_prediction=dataset_for_prediction.dropna()

# date time typecast
dataset_for_prediction['Date'] =pd.to_datetime(dataset_for_prediction['Date'])
dataset_for_prediction.index= dataset_for_prediction['Date']



# normalizing the exogeneous variables
from sklearn.preprocessing import MinMaxScaler
sc_in = MinMaxScaler(feature_range=(0, 1))
scaled_input = sc_in.fit_transform(dataset_for_prediction[['Low', 'High', 'Open', 'Close', 'Volume', 'Mean']])
scaled_input = pd.DataFrame(scaled_input, index=dataset_for_prediction.index)
X=scaled_input
X.rename(columns={0:'Low', 1:'High', 2:'Open', 3:'Close', 4:'Volume', 5:'Mean'}, inplace=True)
print("Normalized X")
print(X.head())


# normalizing the time series
sc_out = MinMaxScaler(feature_range=(0, 1))
scaler_output = sc_out.fit_transform(dataset_for_prediction[['Actual']])
scaler_output =pd.DataFrame(scaler_output, index=dataset_for_prediction.index)
y=scaler_output
y.rename(columns={0:'BTC Price next day'}, inplace= True)
y.index=dataset_for_prediction.index
print("Normalized y")
print(y.head())


# train-test split (cannot shuffle in case of time series)
train_size=int(len(df) *0.9)
test_size = int(len(df)) - train_size
train_X, train_y = X[:train_size].dropna(), y[:train_size].dropna()
test_X, test_y = X[train_size:].dropna(), y[train_size:].dropna()



# Init the best SARIMAX model
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(
    train_y,
    exog=train_X,
    order=(0,1,1),
    seasonal_order =(0, 0, 1, 12),
    enforce_invertibility=False,
    enforce_stationarity=False
)

# training the model
results = model.fit()

# get predictions
predictions = results.predict(start =train_size, end=train_size+test_size-2,exog=test_X)


# setting up for plots
act = pd.DataFrame(scaler_output.iloc[train_size:, 0])
predictions=pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index=test_X.index
predictions['Actual'] = act['BTC Price next day']
predictions.rename(columns={0:'Pred', 'predicted_mean':'Pred'}, inplace=True)


# post-processing inverting normalization
testPredict = sc_out.inverse_transform(predictions[['Pred']])
testActual = sc_out.inverse_transform(predictions[['Actual']])

# prediction plots
plt.figure(figsize=(20,10))
plt.plot(predictions.index, testActual, label='Pred', color='blue')
plt.plot(predictions.index, testPredict, label='Actual', color='red')
plt.legend()
plt.show()

# print RMSE
from statsmodels.tools.eval_measures import rmse
print("RMSE:",rmse(testActual, testPredict))
# Out:
# Normalized X
#                               Low      High      Open     Close  Volume  \
# Date
# 2013-04-30 23:59:59.999  0.003624  0.003616  0.003890  0.003632     0.0
# 2013-05-01 23:59:59.999  0.002231  0.003264  0.003632  0.002499     0.0
# 2013-05-02 23:59:59.999  0.001415  0.002550  0.002467  0.001893     0.0
# 2013-05-03 23:59:59.999  0.000718  0.001677  0.001945  0.001509     0.0
# 2013-05-04 23:59:59.999  0.001427  0.002020  0.001525  0.002268     0.0
#
#                              Mean
# Date
# 2013-04-30 23:59:59.999  0.003592
# 2013-05-01 23:59:59.999  0.002734
# 2013-05-02 23:59:59.999  0.001971
# 2013-05-03 23:59:59.999  0.001183
# 2013-05-04 23:59:59.999  0.001704
# Normalized y
#                          BTC Price next day
# Date
# 2013-04-30 23:59:59.999            0.003605
# 2013-05-01 23:59:59.999            0.003592
# 2013-05-02 23:59:59.999            0.002734
# 2013-05-03 23:59:59.999            0.001971
# 2013-05-04 23:59:59.999            0.001183
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.58094D+00    |proj g|=  1.87305D-01
#  This problem is unconstrained.
# At iterate    5    f= -3.58159D+00    |proj g|=  5.30918D+00
#
# At iterate   10    f= -3.58479D+00    |proj g|=  6.92340D-01
#
# At iterate   15    f= -3.58598D+00    |proj g|=  8.66298D+00
#
# At iterate   20    f= -3.58995D+00    |proj g|=  2.58291D-01
#
# At iterate   25    f= -3.59404D+00    |proj g|=  9.14068D+00
#
# At iterate   30    f= -3.60188D+00    |proj g|=  1.67596D+00
#
# At iterate   35    f= -3.61518D+00    |proj g|=  2.58530D+01
#
# At iterate   40    f= -3.65394D+00    |proj g|=  2.56784D+01
#
# At iterate   45    f= -3.66142D+00    |proj g|=  1.25294D-01
#
# At iterate   50    f= -3.66192D+00    |proj g|=  1.65222D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     50     70      1     0     0   1.652D+00  -3.662D+00
#   F =  -3.6619193648993895
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RMSE: [157.45585423]
